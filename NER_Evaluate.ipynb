# %%
import os
import json

# %%
receipt_text = r"""Marley's Shop
123 Long Rd
Kailua, HI 67530
(808) 555-1234
CASHIER: JOHN
REGISTER #: 6
04/12/2023
Transaction ID: 5769009
PRICE   QTY  TOTAL
APPLES (1 lb)
2.99 2 5.98  1001
-1.00  999
Choco Dream Cookies
7.59 1 7.59   1001
SUBTOTAL
13.57
SALES TAX 8.5%
1.15
TOTAL
-14.72
VISA CARD            14.72
CARD#: ************1234
REFERENCE#: 6789
THANK YOU FOR SHOPPING WITH US!
"""
print(receipt_text)
# Out:
# Marley's Shop
# 123 Long Rd
# Kailua, HI 67530
# (808) 555-1234
# CASHIER: JOHN
# REGISTER #: 6
# 04/12/2023
# Transaction ID: 5769009
# PRICE   QTY  TOTAL
# APPLES (1 lb)
# 2.99 2 5.98  1001
# -1.00  999
# Choco Dream Cookies
# 7.59 1 7.59   1001
# SUBTOTAL
# 13.57
# SALES TAX 8.5%
# 1.15
# TOTAL
# -14.72
# VISA CARD            14.72
# CARD#: ************1234
# REFERENCE#: 6789
# THANK YOU FOR SHOPPING WITH US!

# %%
entities  = """
{
  "ReceiptInfo": {
    "merchant": "Marley's Shop",
    "address": "123 Long Rd",
    "city": "Kailua",
    "state": "HI",
    "phoneNumber": "(808) 555-1234",
    "tax": 1.15,
    "total": 14.72,
    "receiptDate": "04/12/2023",
    "ITEMS": [
      {
        "description": "APPLES (1 lb)",
        "quantity": 2,
        "unitPrice": 2.99,
        "totalPrice": 5.98,
        "discountAmount": 1.00
      },
      {
        "description": "Choco Dream Cookies",
        "quantity": 1,
        "unitPrice": 7.59,
        "totalPrice": 7.59
      }
    ]
  }
}
"""

# %%
os.listdir(ner_eval_folder)
# Out:
# ['5efb55fb-a995-4e73-bb82-05b47d0096b0.txt',
#  '.DS_Store',
#  'f0e3e727-e8fc-4114-95dd-f3b69d36ae06.txt',
#  '5b8e8bcd-9f37-423a-bf56-0cac29bc6c55.txt',
#  '1c4a28f3-3a87-4573-93e9-e71ba8ad06ba.txt',
#  '9d0434ef-1c83-4cb1-8fbd-d54f46828028.txt',
#  '7c1bdf4b-25f8-44d6-949b-77e86ff18944.txt',
#  'annotations',
#  '376aaf32-f8a8-4d53-b76d-5b3c3af73a64.txt',
#  '.ipynb_checkpoints',
#  '7e5c9986-0306-4601-82a3-07f4cedf89c4.txt',
#  '6e2cc2b3-b147-4185-825d-25120df5bf17.txt',
#  '2b26434e-327c-42d6-842c-d0c8bf927711.txt']

# %%
receipt_texts[2]
# Out:
# 'Give us feedback survey.walmart.com Thank you! ID Walmart 808-955-8441 Mgr : WALTER 700 KEEAUMOKU ST HONOLULU HI 96814 ST# 03478 OP# 009038 TE# 38 TR# 02834 SF CANDY 007296564175 F 2.88 X SF CANDY 007296564175 F 2.88 X SF CANDY 007296564175 F 2.88 X FC PB 6CT 081771902035 F 7.68 X TAX 1 0.77 SUBTOTAL 16.32 TOTAL 17.09 VISA TEND 17.09 CHASE VISA **** **** **** 2925 I 1 APPROVAL # 06333D REF # 216400504361 TRANS ID - 582164079306243 VALIDATION - DQQF PAYMENT SERVICE - E AID A0000000031010 AAC 0B27D8374A31A1BF TERMINAL # SC010553 06/12/22 16:12:16 CHANGE DUE 0.00 # ITEMS SOLD 4 TC# 9514 3584 1354 3260 4569 Walmart Become a member today Scan for 30-day free trial. Low Prices You Can Trust. Every Day. 06/12/22 16:12:16 ***CUSTOMER COPY***'

# %%
### type(json.loads(entities))

# %%
### IMPORTANT CELL NUMBER 1 ###


ner_eval_folder = "data/receipts/ner_evaluate"
annotations_folder = "data/receipts/ner_evaluate/annotations"
golden_annotations_path = annotations_folder + "/golden_annotations.json"
classified_annotations_path = annotations_folder + "/classified_ner_evaluate.json"
golden_annotations=[]
classified_annotations = []
with open(classified_annotations_path, 'r') as f:
    classified_annotations = json.load(f)
with open(golden_annotations_path, 'r') as f:
    lines = f.readlines()
    for line in lines:
         json_object = json.loads(line)
         golden_annotations.append(json_object)
receipt_texts = []
for filename in os.listdir(ner_eval_folder):
    if filename.endswith('.txt'):
        with open(os.path.join(ner_eval_folder, filename)) as f:
            return_value = f.read().replace("<UNKNOWN>", "")
            return_value = return_value.replace("UNKNOWN", "")
            return_value = return_value.replace("Unknown", "")
            return_value = return_value.replace("unknown", "")
            return_value = " ".join(return_value.split())
            receipt_texts.append(return_value)

# %%
golden_annotations
# Out:
# [{'ReceiptInfo': {'vendorClassification': 'Grocery and Supermarkets',
#    'merchant': 'COSTCO WHOLESALE',
#    'address': '525 Alakawa St',
#    'city': 'Honolulu',
#    'state': 'HI',
#    'phoneNumber': '',
#    'tax': 3.68,
#    'total': 81.73,
#    'receiptDate': '06/22/2022',
#    'receiptTime': '16:43',
#    'totalItems': 7,
#    'paymentType': 'credit',
#    'diningOptions': '',
#    'creditCardType': 'Visa',
#    'totalDiscount': 0.0,
#    'ITEMS': [{'productClassification': 'Food Products',
#      'description': 'MASHD POTATO',
#      'unabbreviatedDescription': 'Mashed Potatoes',
#      'includedItems': [],
#      'quantity': 1,
#      'unitPrice': 7.49,
#      'totalPrice': 7.49,
#      'discountAmount': 0.0},
#     {'productClassification': 'Beverages',
#      'description': 'WHOLE MILK',
#      'unabbreviatedDescription': 'Whole Milk',
#      'includedItems': [],
#      'quantity': 3,
#      'unitPrice': 5.77,
#      'totalPrice': 17.31,
#      'discountAmount': 0.0},
#     {'productClassification': 'Food Products',
#      'description': 'PINEAPPLE',
#      'unabbreviatedDescription': 'Pineapple',
#      'includedItems': [],
#      'quantity': 1,
#      'unitPrice': 3.69,
#      'totalPrice': 3.69,
#      'discountAmount': 0.0},
#     {'productClassification': 'Food Products',
#      'description': 'SPRING MIX',
#      'unabbreviatedDescription': 'Spring Mix Salad',
#      'includedItems': [],
#      'quantity': 1,
#      'unitPrice': 5.49,
#      'totalPrice': 5.49,
#      'discountAmount': 0.0},
#     {'productClassification': 'Cleaning Supplies',
#      'description': 'KS BAGS 200',
#      'unabbreviatedDescription': 'Kirkland Signature Trash Bags 200 Count',
#      'includedItems': [],
#      'quantity': 1,
#      'unitPrice': 18.89,
#      'totalPrice': 18.89,
#      'discountAmount': 0.0},
#     {'productClassification': 'Food Products',
#      'description': 'MASSAMAN',
#      'unabbreviatedDescription': 'Massaman Curry',
#      'includedItems': [],
#      'quantity': 1,
#      'unitPrice': 8.99,
#      'totalPrice': 8.99,
#      'discountAmount': 0.0},
#     {'productClassification': 'Food Products',
#      'description': 'BEEF BULGOGI',
#      'unabbreviatedDescription': 'Beef Bulgolgi',
#      'includedItems': [],
#      'quantity': 1,
#      'unitPrice': 27.73,
#      'totalPrice': 27.73,
#      'discountAmount': 0.0}]}},
#  {'ReceiptInfo': {'vendorClassification': 'Restaurants and Food Services',
#    'merchant': 'Dunkin',
#    'address': '2560 McCarthy Mall',
#    'city': 'Honolulu',
#    'state': 'HI',
#    'phoneNumber': '(808) 956-6728',
#    'tax': 0.26,
#    'total': 5.85,
#    'receiptDate': '6/26/2023',
#    'receiptTime': '11:09 AM',
#    'totalItems': 1,
#    'paymentType': 'credit',
#    'diningOptions': 'DINE IN',
#    'creditCardType': 'Visa',
#    'totalDiscount': 0.0,
#    'ITEMS': [{'productClassification': 'Food Products',
#      'description': 'Lg Ice Orig Latte',
#      'unabbreviatedDescription': 'Large Original Iced Latte',
#      'includedItems': [],
#      'quantity': 1,
#      'unitPrice': 5.59,
#      'totalPrice': 5.59,
#      'discountAmount': 0.0}]}},
#  {'ReceiptInfo': {'vendorClassification': 'Grocery and Supermarkets',
#    'merchant': 'Walmart',
#    'address': '700 KEEAUMOKU ST',
#    'city': 'HONOLULU',
#    'state': 'HI',
#    'phoneNumber': '808-955-8441',
#    'tax': 0.77,
#    'total': 17.09,
#    'receiptDate': '06/12/22',
#    'receiptTime': '16:12:16',
#    'totalItems': 4,
#    'paymentType': 'credit',
#    'diningOptions': '',
#    'creditCardType': 'CHASE VISA',
#    'totalDiscount': 0.0,
#    'ITEMS': [{'productClassification': 'Food Products',
#      'description': 'SF CANDY',
#      'unabbreviatedDescription': 'Sugar Free Candy',
#      'includedItems': [],
#      'quantity': 3,
#      'unitPrice': 2.88,
#      'totalPrice': 8.64,
#      'discountAmount': 0.0},
#     {'productClassification': 'Food Products',
#      'description': 'FC PB 6CT',
#      'unabbreviatedDescription': 'FITCRUNCH Chocolate Peanut Butter Bar 6 Count',
#      'includedItems': [],
#      'quantity': 1,
#      'unitPrice': 7.68,
#      'totalPrice': 7.68,
#      'discountAmount': 0.0}]}},
#  {'ReceiptInfo': {'vendorClassification': 'Health and Beauty',
#    'merchant': 'Longs',
#    'address': '4211 WAIALAE AVE',
#    'city': '',
#    'state': 'HI',
#    'phoneNumber': '808.732.0781',
#    'tax': 0.75,
#    'total': 16.72,
#    'receiptDate': 'MAY 11, 2022',
#    'receiptTime': '6:44 PM',
#    'totalItems': 3,
#    'paymentType': 'credit',
#    'diningOptions': '',
#    'creditCardType': 'CHASE VISA',
#    'totalDiscount': 0.0,
#    'ITEMS': [{'productClassification': 'Toys and Games',
#      'description': '10RAINBOW PLAYBALL EACH',
#      'unabbreviatedDescription': '10 Rainbow Playground Ball',
#      'includedItems': [],
#      'quantity': 1,
#      'unitPrice': 7.99,
#      'totalPrice': 7.99,
#      'discountAmount': 0.0},
#     {'productClassification': 'Food Products',
#      'description': 'CFRIO SF PEG BAG',
#      'unabbreviatedDescription': 'Coffee Rio Sugar Free Peg Bag',
#      'includedItems': [],
#      'quantity': 2,
#      'unitPrice': 3.99,
#      'totalPrice': 7.98,
#      'discountAmount': 0.0}]}},
#  {'ReceiptInfo': {'vendorClassification': 'Restaurants and Food Services',
#    'merchant': "McDonald's",
#    'address': '94-212 LEOKU ST',
#    'city': 'WAIPAHU',
#    'state': 'HI',
#    'phoneNumber': '808-671-0881',
#    'tax': 0.32,
#    'total': 7.1,
#    'receiptDate': '11/12/2022',
#    'receiptTime': '06:58 PM',
#    'totalItems': 2,
#    'paymentType': 'credit',
#    'diningOptions': 'TO GO',
#    'creditCardType': 'Visa',
#    'totalDiscount': 0.0,
#    'ITEMS': [{'productClassification': 'Food Products',
#      'description': 'Double',
#      'unabbreviatedDescription': 'Double Cheeseburger',
#      'includedItems': ['LIGHT Onions', 'LIGHT Ketchup', 'NO Pickle'],
#      'quantity': 1,
#      'unitPrice': 3.59,
#      'totalPrice': 3.59,
#      'discountAmount': 0.0},
#     {'productClassification': 'Food Products',
#      'description': 'French Fries',
#      'unabbreviatedDescription': 'French Fries',
#      'includedItems': [],
#      'quantity': 1,
#      'unitPrice': 3.19,
#      'totalPrice': 3.19,
#      'discountAmount': 0.0}]}},
#  {'ReceiptInfo': {'vendorClassification': 'Restaurants and Food Services',
#    'merchant': 'Taco Bell',
#    'address': '717 Kapahulu Ave',
#    'city': 'Honolulu',
#    'state': 'HI',
#    'phoneNumber': '(808)737-7337',
#    'tax': 0.28,
#    'total': 6.26,
#    'receiptDate': '10/4/2023',
#    'receiptTime': '7:09:19 PM',
#    'totalItems': 2,
#    'paymentType': 'credit',
#    'diningOptions': '',
#    'creditCardType': 'VISA',
#    'totalDiscount': 0.0,
#    'ITEMS': [{'productClassification': 'Food Products',
#      'description': 'Bean Burrito',
#      'unabbreviatedDescription': 'Bean Burrito',
#      'includedItems': ['No Red Sauce', 'NO Onion', 'Add Beef'],
#      'quantity': 2,
#      'unitPrice': 1.89,
#      'totalPrice': 5.98,
#      'discountAmount': 0.0}]}},
#  {'ReceiptInfo': {'vendorClassification': 'Grocery and Supermarkets',
#    'merchant': "Sam's Club",
#    'address': '',
#    'city': '',
#    'state': '',
#    'phoneNumber': '(808) 945 9841',
#    'tax': 3.32,
#    'total': 74.2,
#    'receiptDate': '05/13/23',
#    'receiptTime': '19:17',
#    'totalItems': 8,
#    'paymentType': 'credit',
#    'diningOptions': '',
#    'creditCardType': 'Discover Credit',
#    'totalDiscount': 1.0,
#    'ITEMS': [{'productClassification': 'Food Products',
#      'description': 'EZPEELSHRINF',
#      'unabbreviatedDescription': 'Easy Peel Shrimp',
#      'includedItems': [],
#      'quantity': 1,
#      'unitPrice': 16.98,
#      'totalPrice': 16.98,
#      'discountAmount': 0.0},
#     {'productClassification': 'Beverages',
#      'description': 'DC 24PK CAN',
#      'unabbreviatedDescription': 'Diet Coke 24 Pack',
#      'includedItems': [],
#      'quantity': 1,
#      'unitPrice': 11.58,
#      'totalPrice': 11.58,
#      'discountAmount': 0.0},
#     {'productClassification': 'Beverages',
#      'description': 'HI DEPOSIT',
#      'unabbreviatedDescription': 'HI Deposit Fee',
#      'includedItems': [],
#      'quantity': 1,
#      'unitPrice': 1.2,
#      'totalPrice': 1.2,
#      'discountAmount': 0.0},
#     {'productClassification': 'Beverages',
#      'description': 'HI HANDLING',
#      'unabbreviatedDescription': 'HI Handling Fee',
#      'includedItems': [],
#      'quantity': 1,
#      'unitPrice': 0.24,
#      'totalPrice': 0.24,
#      'discountAmount': 0.0},
#     {'productClassification': 'Food Products',
#      'description': 'MIXED NUTS',
#      'unabbreviatedDescription': 'Mixed Nuts',
#      'includedItems': [],
#      'quantity': 1,
#      'unitPrice': 9.98,
#      'totalPrice': 9.98,
#      'discountAmount': 0.0},
#     {'productClassification': 'Food Products',
#      'description': 'DORITOS COO',
#      'unabbreviatedDescription': 'Doritos Cool Ranch',
#      'includedItems': [],
#      'quantity': 1,
#      'unitPrice': 5.96,
#      'totalPrice': 5.96,
#      'discountAmount': 1.0},
#     {'productClassification': 'Food Products',
#      'description': 'BASHATI',
#      'unabbreviatedDescription': 'Basmati Rice',
#      'includedItems': [],
#      'quantity': 1,
#      'unitPrice': 19.98,
#      'totalPrice': 19.98,
#      'discountAmount': 0.0},
#     {'productClassification': 'Food Products',
#      'description': '',
#      'unabbreviatedDescription': '150',
#      'includedItems': [],
#      'quantity': 1,
#      'unitPrice': 5.96,
#      'totalPrice': 5.96,
#      'discountAmount': 0.0}]}},
#  {'ReceiptInfo': {'vendorClassification': 'Restaurants and Food Services',
#    'merchant': 'Baskin Robbins',
#    'address': '1618 South King Street',
#    'city': 'Honolulu',
#    'state': 'HI',
#    'phoneNumber': '(808)947-7300',
#    'tax': 0.26,
#    'total': 6.73,
#    'receiptDate': '9/1/2023',
#    'receiptTime': '5:15 PM',
#    'totalItems': 1,
#    'paymentType': 'credit',
#    'diningOptions': 'DINE IN',
#    'creditCardType': 'Visa',
#    'totalDiscount': 0.0,
#    'ITEMS': [{'productClassification': 'Food Products',
#      'description': 'Single Scoop',
#      'unabbreviatedDescription': 'Single Scoop',
#      'includedItems': ['Dip Sugar Cone'],
#      'quantity': 1,
#      'unitPrice': 4.39,
#      'totalPrice': 5.59,
#      'discountAmount': 0.0}]}},
#  {'ReceiptInfo': {'vendorClassification': 'Restaurants and Food Services',
#    'merchant': 'KAHEKA STORE',
#    'address': '',
#    'city': '',
#    'state': '',
#    'phoneNumber': '973-4800',
#    'tax': 0.34,
#    'total': 7.62,
#    'receiptDate': '09/29/2023',
#    'receiptTime': '22:20:44',
#    'totalItems': 2,
#    'paymentType': 'credit',
#    'diningOptions': '',
#    'creditCardType': 'Discover',
#    'totalDiscount': 0.0,
#    'ITEMS': [{'productClassification': 'Food Products',
#      'description': 'JOLLYTIME POPCORN',
#      'unabbreviatedDescription': 'Jollytime Popcorn',
#      'includedItems': [],
#      'quantity': 1,
#      'unitPrice': 3.79,
#      'totalPrice': 3.79,
#      'discountAmount': 0.0},
#     {'productClassification': 'Food Products',
#      'description': 'VARIETY POPCORN BAGS 10 PK',
#      'unabbreviatedDescription': 'Variety Popcorn Bags 10 Pack',
#      'includedItems': [],
#      'quantity': 1,
#      'unitPrice': 3.49,
#      'totalPrice': 3.49,
#      'discountAmount': 0.0}]}},
#  {'ReceiptInfo': {'vendorClassification': 'Grocery and Supermarkets',
#    'merchant': 'WHOLE FOODS MARKET',
#    'address': '388 Kamakee St',
#    'city': 'Honolulu',
#    'state': 'HI',
#    'phoneNumber': '808-379-1800',
#    'tax': 1.22,
#    'total': 27.08,
#    'receiptDate': '04/12/2022',
#    'receiptTime': '07:31 PM',
#    'totalItems': 4,
#    'paymentType': 'credit',
#    'diningOptions': '',
#    'creditCardType': 'VISA',
#    'totalDiscount': 0.0,
#    'ITEMS': [{'productClassification': 'Food Products',
#      'description': '365WFM PASTA SAUCE',
#      'unabbreviatedDescription': 'Pasta Sauce',
#      'includedItems': [],
#      'quantity': 1,
#      'unitPrice': 2.29,
#      'totalPrice': 2.29,
#      'discountAmount': 0.0},
#     {'productClassification': 'Food Products',
#      'description': '365WFM RSTD SLTD ALMDS',
#      'unabbreviatedDescription': 'Roasted Salted Almonds',
#      'includedItems': [],
#      'quantity': 1,
#      'unitPrice': 9.99,
#      'totalPrice': 9.99,
#      'discountAmount': 0.0},
#     {'productClassification': 'Food Products',
#      'description': '365WFM BREADED CALAMARI',
#      'unabbreviatedDescription': 'Breaded Calamari',
#      'includedItems': [],
#      'quantity': 2,
#      'unitPrice': 6.79,
#      'totalPrice': 13.58,
#      'discountAmount': 0.0}]}}]

# %%
ner_scores_golden[6]['scores']
# Out:
# [{'start': -1, 'end': -1, 'label': 'MERCHANT'},
#  {'start': 0, 'end': 0, 'label': 'ADDRESS'},
#  {'start': 0, 'end': 0, 'label': 'CITY'},
#  {'start': 0, 'end': 0, 'label': 'STATE'},
#  {'start': -1, 'end': -1, 'label': 'PHONE'},
#  {'start': 389, 'end': 393, 'label': 'TAX'},
#  {'start': 400, 'end': 404, 'label': 'TOTAL'},
#  {'start': 64, 'end': 72, 'label': 'DATE'},
#  {'start': 73, 'end': 78, 'label': 'TIME'},
#  {'start': 113, 'end': 125, 'label': 'ITEM_DESC'},
#  {'start': 62, 'end': 63, 'label': 'QTY'},
#  {'start': 126, 'end': 131, 'label': 'UNIT_PRICE'},
#  {'start': 126, 'end': 131, 'label': 'TOTAL_PRICE'},
#  {'start': 144, 'end': 155, 'label': 'ITEM_DESC'},
#  {'start': 62, 'end': 63, 'label': 'QTY'},
#  {'start': 157, 'end': 162, 'label': 'UNIT_PRICE'},
#  {'start': 157, 'end': 162, 'label': 'TOTAL_PRICE'},
#  {'start': 175, 'end': 185, 'label': 'ITEM_DESC'},
#  {'start': 62, 'end': 63, 'label': 'QTY'},
#  {'start': 188, 'end': 191, 'label': 'UNIT_PRICE'},
#  {'start': 188, 'end': 191, 'label': 'TOTAL_PRICE'},
#  {'start': 207, 'end': 218, 'label': 'ITEM_DESC'},
#  {'start': 62, 'end': 63, 'label': 'QTY'},
#  {'start': 220, 'end': 224, 'label': 'UNIT_PRICE'},
#  {'start': 220, 'end': 224, 'label': 'TOTAL_PRICE'},
#  {'start': 239, 'end': 249, 'label': 'ITEM_DESC'},
#  {'start': 62, 'end': 63, 'label': 'QTY'},
#  {'start': 252, 'end': 256, 'label': 'UNIT_PRICE'},
#  {'start': 252, 'end': 256, 'label': 'TOTAL_PRICE'},
#  {'start': 272, 'end': 283, 'label': 'ITEM_DESC'},
#  {'start': 62, 'end': 63, 'label': 'QTY'},
#  {'start': 285, 'end': 289, 'label': 'UNIT_PRICE'},
#  {'start': 285, 'end': 289, 'label': 'TOTAL_PRICE'},
#  {'start': 361, 'end': 364, 'label': 'DISCOUNT'},
#  {'start': 323, 'end': 330, 'label': 'ITEM_DESC'},
#  {'start': 62, 'end': 63, 'label': 'QTY'},
#  {'start': 331, 'end': 336, 'label': 'UNIT_PRICE'},
#  {'start': 331, 'end': 336, 'label': 'TOTAL_PRICE'},
#  {'start': 302, 'end': 305, 'label': 'ITEM_DESC'},
#  {'start': 62, 'end': 63, 'label': 'QTY'},
#  {'start': 285, 'end': 289, 'label': 'UNIT_PRICE'},
#  {'start': 285, 'end': 289, 'label': 'TOTAL_PRICE'}]

# %%
ner_scores_classified[6]['scores']
# Out:
# [{'start': -1, 'end': -1, 'label': 'MERCHANT'},
#  {'start': 0, 'end': 0, 'label': 'ADDRESS'},
#  {'start': 0, 'end': 0, 'label': 'CITY'},
#  {'start': 0, 'end': 0, 'label': 'STATE'},
#  {'start': -1, 'end': -1, 'label': 'PHONE'},
#  {'start': 389, 'end': 393, 'label': 'TAX'},
#  {'start': 400, 'end': 404, 'label': 'TOTAL'},
#  {'start': 64, 'end': 72, 'label': 'DATE'},
#  {'start': 73, 'end': 78, 'label': 'TIME'},
#  {'start': 113, 'end': 125, 'label': 'ITEM_DESC'},
#  {'start': 62, 'end': 63, 'label': 'QTY'},
#  {'start': 126, 'end': 131, 'label': 'UNIT_PRICE'},
#  {'start': 126, 'end': 131, 'label': 'TOTAL_PRICE'},
#  {'start': 144, 'end': 156, 'label': 'ITEM_DESC'},
#  {'start': 62, 'end': 63, 'label': 'QTY'},
#  {'start': 157, 'end': 162, 'label': 'UNIT_PRICE'},
#  {'start': 157, 'end': 162, 'label': 'TOTAL_PRICE'},
#  {'start': 175, 'end': 187, 'label': 'ITEM_DESC'},
#  {'start': 62, 'end': 63, 'label': 'QTY'},
#  {'start': 188, 'end': 191, 'label': 'UNIT_PRICE'},
#  {'start': 188, 'end': 191, 'label': 'TOTAL_PRICE'},
#  {'start': 207, 'end': 219, 'label': 'ITEM_DESC'},
#  {'start': 62, 'end': 63, 'label': 'QTY'},
#  {'start': 220, 'end': 224, 'label': 'UNIT_PRICE'},
#  {'start': 220, 'end': 224, 'label': 'TOTAL_PRICE'},
#  {'start': 239, 'end': 251, 'label': 'ITEM_DESC'},
#  {'start': 62, 'end': 63, 'label': 'QTY'},
#  {'start': 252, 'end': 256, 'label': 'UNIT_PRICE'},
#  {'start': 252, 'end': 256, 'label': 'TOTAL_PRICE'},
#  {'start': 272, 'end': 284, 'label': 'ITEM_DESC'},
#  {'start': 62, 'end': 63, 'label': 'QTY'},
#  {'start': 285, 'end': 289, 'label': 'UNIT_PRICE'},
#  {'start': -1, 'end': -1, 'label': 'TOTAL_PRICE'},
#  {'start': 361, 'end': 364, 'label': 'DISCOUNT'},
#  {'start': 62, 'end': 63, 'label': 'QTY'},
#  {'start': 285, 'end': 289, 'label': 'UNIT_PRICE'},
#  {'start': 285, 'end': 289, 'label': 'TOTAL_PRICE'},
#  {'start': 323, 'end': 330, 'label': 'ITEM_DESC'},
#  {'start': 62, 'end': 63, 'label': 'QTY'},
#  {'start': 331, 'end': 336, 'label': 'UNIT_PRICE'},
#  {'start': 331, 'end': 336, 'label': 'TOTAL_PRICE'}]

# %%
### IMPORTANT CELL NUMBER 2###
ner_scores_golden = []
ner_scores_classified = []
for pair in zip(receipt_texts, golden_annotations):
    prodigy_spans, text_vals = convert_to_prodigy_spans(pair[0], pair[1])
    ner_scores_golden.append({"scores": prodigy_spans, "text_values": text_vals})
for pair in zip(receipt_texts, classified_annotations):
    prodigy_spans, text_vals = convert_to_prodigy_spans(pair[0], pair[1])
    ner_scores_classified.append({"scores": prodigy_spans, "text_values": text_vals})

# %%
ner_scores_golden
# Out:
# [{'scores': [{'start': 0, 'end': 16, 'label': 'MERCHANT'},
#    {'start': 29, 'end': 43, 'label': 'ADDRESS'},
#    {'start': 44, 'end': 52, 'label': 'CITY'},
#    {'start': 54, 'end': 56, 'label': 'STATE'},
#    {'start': 0, 'end': 0, 'label': 'PHONE'},
#    {'start': 289, 'end': 293, 'label': 'TAX'},
#    {'start': 305, 'end': 310, 'label': 'TOTAL'},
#    {'start': 451, 'end': 461, 'label': 'DATE'},
#    {'start': 462, 'end': 467, 'label': 'TIME'},
#    {'start': 95, 'end': 107, 'label': 'ITEM_DESC'},
#    {'start': 60, 'end': 61, 'label': 'QTY'},
#    {'start': 108, 'end': 112, 'label': 'UNIT_PRICE'},
#    {'start': 108, 'end': 112, 'label': 'TOTAL_PRICE'},
#    {'start': 119, 'end': 129, 'label': 'ITEM_DESC'},
#    {'start': 93, 'end': 94, 'label': 'QTY'},
#    {'start': 130, 'end': 134, 'label': 'UNIT_PRICE'},
#    {'start': -1, 'end': -1, 'label': 'TOTAL_PRICE'},
#    {'start': 144, 'end': 153, 'label': 'ITEM_DESC'},
#    {'start': 60, 'end': 61, 'label': 'QTY'},
#    {'start': 154, 'end': 158, 'label': 'UNIT_PRICE'},
#    {'start': 154, 'end': 158, 'label': 'TOTAL_PRICE'},
#    {'start': 169, 'end': 179, 'label': 'ITEM_DESC'},
#    {'start': 60, 'end': 61, 'label': 'QTY'},
#    {'start': 180, 'end': 184, 'label': 'UNIT_PRICE'},
#    {'start': 180, 'end': 184, 'label': 'TOTAL_PRICE'},
#    {'start': 195, 'end': 206, 'label': 'ITEM_DESC'},
#    {'start': 60, 'end': 61, 'label': 'QTY'},
#    {'start': 207, 'end': 212, 'label': 'UNIT_PRICE'},
#    {'start': 207, 'end': 212, 'label': 'TOTAL_PRICE'},
#    {'start': 225, 'end': 233, 'label': 'ITEM_DESC'},
#    {'start': 60, 'end': 61, 'label': 'QTY'},
#    {'start': 234, 'end': 238, 'label': 'UNIT_PRICE'},
#    {'start': 234, 'end': 238, 'label': 'TOTAL_PRICE'},
#    {'start': 249, 'end': 261, 'label': 'ITEM_DESC'},
#    {'start': 60, 'end': 61, 'label': 'QTY'},
#    {'start': 262, 'end': 267, 'label': 'UNIT_PRICE'},
#    {'start': 262, 'end': 267, 'label': 'TOTAL_PRICE'}],
#   'text_values': {'MERCHANT': 'COSTCO WHOLESALE',
#    'ADDRESS': '525 Alakawa St',
#    'CITY': 'Honolulu',
#    'STATE': 'HI',
#    'PHONE': '',
#    'TAX': '3.68',
#    'TOTAL': '81.73',
#    'DATE': '06/22/2022',
#    'TIME': '16:43',
#    'ITEM_DESC': 'BEEF BULGOGI',
#    'QTY': '1',
#    'UNIT_PRICE': '27.73',
#    'TOTAL_PRICE': '27.73'}},
#  {'scores': [{'start': 11, 'end': 17, 'label': 'MERCHANT'},
#    {'start': 31, 'end': 49, 'label': 'ADDRESS'},
#    {'start': 50, 'end': 58, 'label': 'CITY'},
#    {'start': 60, 'end': 62, 'label': 'STATE'},
#    {'start': 69, 'end': 83, 'label': 'PHONE'},
#    {'start': 429, 'end': 433, 'label': 'TAX'},
#    {'start': 164, 'end': 168, 'label': 'TOTAL'},
#    {'start': 107, 'end': 116, 'label': 'DATE'},
#    {'start': 117, 'end': 125, 'label': 'TIME'},
#    {'start': 135, 'end': 152, 'label': 'ITEM_DESC'},
#    {'start': 84, 'end': 85, 'label': 'QTY'},
#    {'start': 153, 'end': 157, 'label': 'UNIT_PRICE'},
#    {'start': 153, 'end': 157, 'label': 'TOTAL_PRICE'}],
#   'text_values': {'MERCHANT': 'Dunkin',
#    'ADDRESS': '2560 McCarthy Mall',
#    'CITY': 'Honolulu',
#    'STATE': 'HI',
#    'PHONE': '(808) 956-6728',
#    'TAX': '0.26',
#    'TOTAL': '5.85',
#    'DATE': '6/26/2023',
#    'TIME': '11:09 AM',
#    'ITEM_DESC': 'Lg Ice Orig Latte',
#    'QTY': '1',
#    'UNIT_PRICE': '5.59',
#    'TOTAL_PRICE': '5.59'}},
#  {'scores': [{'start': 50, 'end': 57, 'label': 'MERCHANT'},
#    {'start': 84, 'end': 100, 'label': 'ADDRESS'},
#    {'start': 101, 'end': 109, 'label': 'CITY'},
#    {'start': 110, 'end': 112, 'label': 'STATE'},
#    {'start': 58, 'end': 70, 'label': 'PHONE'},
#    {'start': 288, 'end': 292, 'label': 'TAX'},
#    {'start': 314, 'end': 319, 'label': 'TOTAL'},
#    {'start': 533, 'end': 541, 'label': 'DATE'},
#    {'start': 542, 'end': 550, 'label': 'TIME'},
#    {'start': 157, 'end': 165, 'label': 'ITEM_DESC'},
#    {'start': 124, 'end': 125, 'label': 'QTY'},
#    {'start': 181, 'end': 185, 'label': 'UNIT_PRICE'},
#    {'start': -1, 'end': -1, 'label': 'TOTAL_PRICE'},
#    {'start': 250, 'end': 259, 'label': 'ITEM_DESC'},
#    {'start': 69, 'end': 70, 'label': 'QTY'},
#    {'start': 275, 'end': 279, 'label': 'UNIT_PRICE'},
#    {'start': 275, 'end': 279, 'label': 'TOTAL_PRICE'}],
#   'text_values': {'MERCHANT': 'Walmart',
#    'ADDRESS': '700 KEEAUMOKU ST',
#    'CITY': 'HONOLULU',
#    'STATE': 'HI',
#    'PHONE': '808-955-8441',
#    'TAX': '0.77',
#    'TOTAL': '17.09',
#    'DATE': '06/12/22',
#    'TIME': '16:12:16',
#    'ITEM_DESC': 'FC PB 6CT',
#    'QTY': '1',
#    'UNIT_PRICE': '7.68',
#    'TOTAL_PRICE': '7.68'}},
#  {'scores': [{'start': 0, 'end': 5, 'label': 'MERCHANT'},
#    {'start': 6, 'end': 22, 'label': 'ADDRESS'},
#    {'start': 0, 'end': 0, 'label': 'CITY'},
#    {'start': 23, 'end': 25, 'label': 'STATE'},
#    {'start': 32, 'end': 44, 'label': 'PHONE'},
#    {'start': -1, 'end': -1, 'label': 'TAX'},
#    {'start': 220, 'end': 225, 'label': 'TOTAL'},
#    {'start': 606, 'end': 618, 'label': 'DATE'},
#    {'start': 619, 'end': 626, 'label': 'TIME'},
#    {'start': 85, 'end': 108, 'label': 'ITEM_DESC'},
#    {'start': 8, 'end': 9, 'label': 'QTY'},
#    {'start': 109, 'end': 113, 'label': 'UNIT_PRICE'},
#    {'start': 109, 'end': 113, 'label': 'TOTAL_PRICE'},
#    {'start': 117, 'end': 133, 'label': 'ITEM_DESC'},
#    {'start': 7, 'end': 8, 'label': 'QTY'},
#    {'start': 137, 'end': 141, 'label': 'UNIT_PRICE'},
#    {'start': -1, 'end': -1, 'label': 'TOTAL_PRICE'}],
#   'text_values': {'MERCHANT': 'Longs',
#    'ADDRESS': '4211 WAIALAE AVE',
#    'CITY': '',
#    'STATE': 'HI',
#    'PHONE': '808.732.0781',
#    'TAX': '0.75',
#    'TOTAL': '16.72',
#    'DATE': 'MAY 11, 2022',
#    'TIME': '6:44 PM',
#    'ITEM_DESC': 'CFRIO SF PEG BAG',
#    'QTY': '2',
#    'UNIT_PRICE': '3.99',
#    'TOTAL_PRICE': '7.98'}},
#  {'scores': [{'start': 195, 'end': 205, 'label': 'MERCHANT'},
#    {'start': 270, 'end': 285, 'label': 'ADDRESS'},
#    {'start': 286, 'end': 293, 'label': 'CITY'},
#    {'start': 294, 'end': 296, 'label': 'STATE'},
#    {'start': 308, 'end': 320, 'label': 'PHONE'},
#    {'start': 447, 'end': 451, 'label': 'TAX'},
#    {'start': 467, 'end': 470, 'label': 'TOTAL'},
#    {'start': 323, 'end': 333, 'label': 'DATE'},
#    {'start': 334, 'end': 342, 'label': 'TIME'},
#    {'start': 360, 'end': 366, 'label': 'ITEM_DESC'},
#    {'start': 230, 'end': 231, 'label': 'QTY'},
#    {'start': 367, 'end': 371, 'label': 'UNIT_PRICE'},
#    {'start': 367, 'end': 371, 'label': 'TOTAL_PRICE'},
#    {'start': 411, 'end': 423, 'label': 'ITEM_DESC'},
#    {'start': 230, 'end': 231, 'label': 'QTY'},
#    {'start': 424, 'end': 428, 'label': 'UNIT_PRICE'},
#    {'start': 424, 'end': 428, 'label': 'TOTAL_PRICE'}],
#   'text_values': {'MERCHANT': "McDonald's",
#    'ADDRESS': '94-212 LEOKU ST',
#    'CITY': 'WAIPAHU',
#    'STATE': 'HI',
#    'PHONE': '808-671-0881',
#    'TAX': '0.32',
#    'TOTAL': '7.1',
#    'DATE': '11/12/2022',
#    'TIME': '06:58 PM',
#    'ITEM_DESC': 'French Fries',
#    'QTY': '1',
#    'UNIT_PRICE': '3.19',
#    'TOTAL_PRICE': '3.19'}},
#  {'scores': [{'start': 85, 'end': 94, 'label': 'MERCHANT'},
#    {'start': 102, 'end': 118, 'label': 'ADDRESS'},
#    {'start': 119, 'end': 127, 'label': 'CITY'},
#    {'start': 129, 'end': 131, 'label': 'STATE'},
#    {'start': 143, 'end': 156, 'label': 'PHONE'},
#    {'start': 303, 'end': 307, 'label': 'TAX'},
#    {'start': 314, 'end': 318, 'label': 'TOTAL'},
#    {'start': 157, 'end': 166, 'label': 'DATE'},
#    {'start': 167, 'end': 177, 'label': 'TIME'},
#    {'start': 210, 'end': 222, 'label': 'ITEM_DESC'},
#    {'start': 71, 'end': 72, 'label': 'QTY'},
#    {'start': -1, 'end': -1, 'label': 'UNIT_PRICE'},
#    {'start': 294, 'end': 298, 'label': 'TOTAL_PRICE'}],
#   'text_values': {'MERCHANT': 'Taco Bell',
#    'ADDRESS': '717 Kapahulu Ave',
#    'CITY': 'Honolulu',
#    'STATE': 'HI',
#    'PHONE': '(808)737-7337',
#    'TAX': '0.28',
#    'TOTAL': '6.26',
#    'DATE': '10/4/2023',
#    'TIME': '7:09:19 PM',
#    'ITEM_DESC': 'Bean Burrito',
#    'QTY': '2',
#    'UNIT_PRICE': '1.89',
#    'TOTAL_PRICE': '5.98'}},
#  {'scores': [{'start': -1, 'end': -1, 'label': 'MERCHANT'},
#    {'start': 0, 'end': 0, 'label': 'ADDRESS'},
#    {'start': 0, 'end': 0, 'label': 'CITY'},
#    {'start': 0, 'end': 0, 'label': 'STATE'},
#    {'start': -1, 'end': -1, 'label': 'PHONE'},
#    {'start': 389, 'end': 393, 'label': 'TAX'},
#    {'start': 400, 'end': 404, 'label': 'TOTAL'},
#    {'start': 64, 'end': 72, 'label': 'DATE'},
#    {'start': 73, 'end': 78, 'label': 'TIME'},
#    {'start': 113, 'end': 125, 'label': 'ITEM_DESC'},
#    {'start': 62, 'end': 63, 'label': 'QTY'},
#    {'start': 126, 'end': 131, 'label': 'UNIT_PRICE'},
#    {'start': 126, 'end': 131, 'label': 'TOTAL_PRICE'},
#    {'start': 144, 'end': 155, 'label': 'ITEM_DESC'},
#    {'start': 62, 'end': 63, 'label': 'QTY'},
#    {'start': 157, 'end': 162, 'label': 'UNIT_PRICE'},
#    {'start': 157, 'end': 162, 'label': 'TOTAL_PRICE'},
#    {'start': 175, 'end': 185, 'label': 'ITEM_DESC'},
#    {'start': 62, 'end': 63, 'label': 'QTY'},
#    {'start': 188, 'end': 191, 'label': 'UNIT_PRICE'},
#    {'start': 188, 'end': 191, 'label': 'TOTAL_PRICE'},
#    {'start': 207, 'end': 218, 'label': 'ITEM_DESC'},
#    {'start': 62, 'end': 63, 'label': 'QTY'},
#    {'start': 220, 'end': 224, 'label': 'UNIT_PRICE'},
#    {'start': 220, 'end': 224, 'label': 'TOTAL_PRICE'},
#    {'start': 239, 'end': 249, 'label': 'ITEM_DESC'},
#    {'start': 62, 'end': 63, 'label': 'QTY'},
#    {'start': 252, 'end': 256, 'label': 'UNIT_PRICE'},
#    {'start': 252, 'end': 256, 'label': 'TOTAL_PRICE'},
#    {'start': 272, 'end': 283, 'label': 'ITEM_DESC'},
#    {'start': 62, 'end': 63, 'label': 'QTY'},
#    {'start': 285, 'end': 289, 'label': 'UNIT_PRICE'},
#    {'start': 285, 'end': 289, 'label': 'TOTAL_PRICE'},
#    {'start': 361, 'end': 364, 'label': 'DISCOUNT'},
#    {'start': 323, 'end': 330, 'label': 'ITEM_DESC'},
#    {'start': 62, 'end': 63, 'label': 'QTY'},
#    {'start': 331, 'end': 336, 'label': 'UNIT_PRICE'},
#    {'start': 331, 'end': 336, 'label': 'TOTAL_PRICE'},
#    {'start': 62, 'end': 63, 'label': 'QTY'},
#    {'start': 285, 'end': 289, 'label': 'UNIT_PRICE'},
#    {'start': 285, 'end': 289, 'label': 'TOTAL_PRICE'}],
#   'text_values': {'MERCHANT': "Sam's Club",
#    'ADDRESS': '',
#    'CITY': '',
#    'STATE': '',
#    'PHONE': '(808) 945 9841',
#    'TAX': '3.32',
#    'TOTAL': '74.2',
#    'DATE': '05/13/23',
#    'TIME': '19:17',
#    'ITEM_DESC': 'BASHATI',
#    'QTY': '1',
#    'UNIT_PRICE': '5.96',
#    'TOTAL_PRICE': '5.96',
#    'DISCOUNT': '1.0'}},
#  {'scores': [{'start': 0, 'end': 14, 'label': 'MERCHANT'},
#    {'start': 26, 'end': 48, 'label': 'ADDRESS'},
#    {'start': 49, 'end': 57, 'label': 'CITY'},
#    {'start': 59, 'end': 61, 'label': 'STATE'},
#    {'start': 68, 'end': 81, 'label': 'PHONE'},
#    {'start': 488, 'end': 492, 'label': 'TAX'},
#    {'start': 195, 'end': 199, 'label': 'TOTAL'},
#    {'start': 106, 'end': 114, 'label': 'DATE'},
#    {'start': 115, 'end': 122, 'label': 'TIME'},
#    {'start': 132, 'end': 144, 'label': 'ITEM_DESC'},
#    {'start': 26, 'end': 27, 'label': 'QTY'},
#    {'start': 145, 'end': 149, 'label': 'UNIT_PRICE'},
#    {'start': 461, 'end': 465, 'label': 'TOTAL_PRICE'}],
#   'text_values': {'MERCHANT': 'Baskin Robbins',
#    'ADDRESS': '1618 South King Street',
#    'CITY': 'Honolulu',
#    'STATE': 'HI',
#    'PHONE': '(808)947-7300',
#    'TAX': '0.26',
#    'TOTAL': '6.73',
#    'DATE': '9/1/2023',
#    'TIME': '5:15 PM',
#    'ITEM_DESC': 'Single Scoop',
#    'QTY': '1',
#    'UNIT_PRICE': '4.39',
#    'TOTAL_PRICE': '5.59'}},
#  {'scores': [{'start': 14, 'end': 26, 'label': 'MERCHANT'},
#    {'start': 0, 'end': 0, 'label': 'ADDRESS'},
#    {'start': 0, 'end': 0, 'label': 'CITY'},
#    {'start': 0, 'end': 0, 'label': 'STATE'},
#    {'start': 32, 'end': 40, 'label': 'PHONE'},
#    {'start': 513, 'end': 517, 'label': 'TAX'},
#    {'start': 309, 'end': 313, 'label': 'TOTAL'},
#    {'start': 71, 'end': 81, 'label': 'DATE'},
#    {'start': 82, 'end': 90, 'label': 'TIME'},
#    {'start': 363, 'end': 380, 'label': 'ITEM_DESC'},
#    {'start': 179, 'end': 180, 'label': 'QTY'},
#    {'start': 382, 'end': 386, 'label': 'UNIT_PRICE'},
#    {'start': 382, 'end': 386, 'label': 'TOTAL_PRICE'},
#    {'start': 391, 'end': 417, 'label': 'ITEM_DESC'},
#    {'start': 179, 'end': 180, 'label': 'QTY'},
#    {'start': 419, 'end': 423, 'label': 'UNIT_PRICE'},
#    {'start': 419, 'end': 423, 'label': 'TOTAL_PRICE'}],
#   'text_values': {'MERCHANT': 'KAHEKA STORE',
#    'ADDRESS': '',
#    'CITY': '',
#    'STATE': '',
#    'PHONE': '973-4800',
#    'TAX': '0.34',
#    'TOTAL': '7.62',
#    'DATE': '09/29/2023',
#    'TIME': '22:20:44',
#    'ITEM_DESC': 'VARIETY POPCORN BAGS 10 PK',
#    'QTY': '1',
#    'UNIT_PRICE': '3.49',
#    'TOTAL_PRICE': '3.49'}},
#  {'scores': [{'start': 0, 'end': 18, 'label': 'MERCHANT'},
#    {'start': 42, 'end': 56, 'label': 'ADDRESS'},
#    {'start': 65, 'end': 73, 'label': 'CITY'},
#    {'start': 75, 'end': 77, 'label': 'STATE'},
#    {'start': 29, 'end': 41, 'label': 'PHONE'},
#    {'start': 243, 'end': 247, 'label': 'TAX'},
#    {'start': 256, 'end': 261, 'label': 'TOTAL'},
#    {'start': 808, 'end': 818, 'label': 'DATE'},
#    {'start': 819, 'end': 827, 'label': 'TIME'},
#    {'start': 89, 'end': 107, 'label': 'ITEM_DESC'},
#    {'start': 37, 'end': 38, 'label': 'QTY'},
#    {'start': 109, 'end': 113, 'label': 'UNIT_PRICE'},
#    {'start': 109, 'end': 113, 'label': 'TOTAL_PRICE'},
#    {'start': 117, 'end': 139, 'label': 'ITEM_DESC'},
#    {'start': 37, 'end': 38, 'label': 'QTY'},
#    {'start': 141, 'end': 145, 'label': 'UNIT_PRICE'},
#    {'start': 141, 'end': 145, 'label': 'TOTAL_PRICE'},
#    {'start': 149, 'end': 172, 'label': 'ITEM_DESC'},
#    {'start': 85, 'end': 86, 'label': 'QTY'},
#    {'start': 178, 'end': 182, 'label': 'UNIT_PRICE'},
#    {'start': 187, 'end': 192, 'label': 'TOTAL_PRICE'}],
#   'text_values': {'MERCHANT': 'WHOLE FOODS MARKET',
#    'ADDRESS': '388 Kamakee St',
#    'CITY': 'Honolulu',
#    'STATE': 'HI',
#    'PHONE': '808-379-1800',
#    'TAX': '1.22',
#    'TOTAL': '27.08',
#    'DATE': '04/12/2022',
#    'TIME': '07:31 PM',
#    'ITEM_DESC': '365WFM BREADED CALAMARI',
#    'QTY': '2',
#    'UNIT_PRICE': '6.79',
#    'TOTAL_PRICE': '13.58'}}]

# %%
# true = ner_scores_golden['scores']

# pred = ner_scores_classified['scores']



overall_results = []
overall_results_per_tag = []
i = 0
for pair in zip(ner_scores_golden, ner_scores_classified):
    
    print()
    print(i)
    true = [[score] for score in pair[0]['scores']]
    print(true)
    pred = [[score] for score in pair[1]['scores']]
    results, results_per_tag = Evaluator(true, pred, 
                                         tags=['MERCHANT', 'ADDRESS', 'CITY', 'STATE', 'PHONE', 'TAX', 'TOTAL', 'DATE', 'TIME', 'ITEM_DESC', 'QTY', 'UNIT_PRICE', 'TOTAL_PRICE']
                                        ).evaluate()
    print(results)
    overall_results.append(results)
    overall_results_per_tag.append(results_per_tag)
    i+=1

# Returns overall metrics and metrics for each tag
# Out:
# 0
# [[{'start': 0, 'end': 16, 'label': 'MERCHANT'}], [{'start': 29, 'end': 43, 'label': 'ADDRESS'}], [{'start': 44, 'end': 52, 'label': 'CITY'}], [{'start': 54, 'end': 56, 'label': 'STATE'}], [{'start': 0, 'end': 0, 'label': 'PHONE'}], [{'start': 289, 'end': 293, 'label': 'TAX'}], [{'start': 305, 'end': 310, 'label': 'TOTAL'}], [{'start': 451, 'end': 461, 'label': 'DATE'}], [{'start': 462, 'end': 467, 'label': 'TIME'}], [{'start': 95, 'end': 107, 'label': 'ITEM_DESC'}], [{'start': 60, 'end': 61, 'label': 'QTY'}], [{'start': 108, 'end': 112, 'label': 'UNIT_PRICE'}], [{'start': 108, 'end': 112, 'label': 'TOTAL_PRICE'}], [{'start': 119, 'end': 129, 'label': 'ITEM_DESC'}], [{'start': 93, 'end': 94, 'label': 'QTY'}], [{'start': 130, 'end': 134, 'label': 'UNIT_PRICE'}], [{'start': -1, 'end': -1, 'label': 'TOTAL_PRICE'}], [{'start': 144, 'end': 153, 'label': 'ITEM_DESC'}], [{'start': 60, 'end': 61, 'label': 'QTY'}], [{'start': 154, 'end': 158, 'label': 'UNIT_PRICE'}], [{'start': 154, 'end': 158, 'label': 'TOTAL_PRICE'}], [{'start': 169, 'end': 179, 'label': 'ITEM_DESC'}], [{'start': 60, 'end': 61, 'label': 'QTY'}], [{'start': 180, 'end': 184, 'label': 'UNIT_PRICE'}], [{'start': 180, 'end': 184, 'label': 'TOTAL_PRICE'}], [{'start': 195, 'end': 206, 'label': 'ITEM_DESC'}], [{'start': 60, 'end': 61, 'label': 'QTY'}], [{'start': 207, 'end': 212, 'label': 'UNIT_PRICE'}], [{'start': 207, 'end': 212, 'label': 'TOTAL_PRICE'}], [{'start': 225, 'end': 233, 'label': 'ITEM_DESC'}], [{'start': 60, 'end': 61, 'label': 'QTY'}], [{'start': 234, 'end': 238, 'label': 'UNIT_PRICE'}], [{'start': 234, 'end': 238, 'label': 'TOTAL_PRICE'}], [{'start': 249, 'end': 261, 'label': 'ITEM_DESC'}], [{'start': 60, 'end': 61, 'label': 'QTY'}], [{'start': 262, 'end': 267, 'label': 'UNIT_PRICE'}], [{'start': 262, 'end': 267, 'label': 'TOTAL_PRICE'}]]
# {'ent_type': {'correct': 36, 'incorrect': 0, 'partial': 0, 'missed': 1, 'spurious': 1, 'possible': 37, 'actual': 37, 'precision': 0.972972972972973, 'recall': 0.972972972972973, 'f1': 0.972972972972973}, 'partial': {'correct': 36, 'incorrect': 0, 'partial': 0, 'missed': 1, 'spurious': 1, 'possible': 37, 'actual': 37, 'precision': 0.972972972972973, 'recall': 0.972972972972973, 'f1': 0.972972972972973}, 'strict': {'correct': 36, 'incorrect': 0, 'partial': 0, 'missed': 1, 'spurious': 1, 'possible': 37, 'actual': 37, 'precision': 0.972972972972973, 'recall': 0.972972972972973, 'f1': 0.972972972972973}, 'exact': {'correct': 36, 'incorrect': 0, 'partial': 0, 'missed': 1, 'spurious': 1, 'possible': 37, 'actual': 37, 'precision': 0.972972972972973, 'recall': 0.972972972972973, 'f1': 0.972972972972973}}
#
# 1
# [[{'start': 11, 'end': 17, 'label': 'MERCHANT'}], [{'start': 31, 'end': 49, 'label': 'ADDRESS'}], [{'start': 50, 'end': 58, 'label': 'CITY'}], [{'start': 60, 'end': 62, 'label': 'STATE'}], [{'start': 69, 'end': 83, 'label': 'PHONE'}], [{'start': 429, 'end': 433, 'label': 'TAX'}], [{'start': 164, 'end': 168, 'label': 'TOTAL'}], [{'start': 107, 'end': 116, 'label': 'DATE'}], [{'start': 117, 'end': 125, 'label': 'TIME'}], [{'start': 135, 'end': 152, 'label': 'ITEM_DESC'}], [{'start': 84, 'end': 85, 'label': 'QTY'}], [{'start': 153, 'end': 157, 'label': 'UNIT_PRICE'}], [{'start': 153, 'end': 157, 'label': 'TOTAL_PRICE'}]]
# {'ent_type': {'correct': 13, 'incorrect': 0, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 13, 'actual': 13, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}, 'partial': {'correct': 13, 'incorrect': 0, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 13, 'actual': 13, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}, 'strict': {'correct': 13, 'incorrect': 0, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 13, 'actual': 13, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}, 'exact': {'correct': 13, 'incorrect': 0, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 13, 'actual': 13, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}}
#
# 2
# [[{'start': 50, 'end': 57, 'label': 'MERCHANT'}], [{'start': 84, 'end': 100, 'label': 'ADDRESS'}], [{'start': 101, 'end': 109, 'label': 'CITY'}], [{'start': 110, 'end': 112, 'label': 'STATE'}], [{'start': 58, 'end': 70, 'label': 'PHONE'}], [{'start': 288, 'end': 292, 'label': 'TAX'}], [{'start': 314, 'end': 319, 'label': 'TOTAL'}], [{'start': 533, 'end': 541, 'label': 'DATE'}], [{'start': 542, 'end': 550, 'label': 'TIME'}], [{'start': 157, 'end': 165, 'label': 'ITEM_DESC'}], [{'start': 124, 'end': 125, 'label': 'QTY'}], [{'start': 181, 'end': 185, 'label': 'UNIT_PRICE'}], [{'start': -1, 'end': -1, 'label': 'TOTAL_PRICE'}], [{'start': 250, 'end': 259, 'label': 'ITEM_DESC'}], [{'start': 69, 'end': 70, 'label': 'QTY'}], [{'start': 275, 'end': 279, 'label': 'UNIT_PRICE'}], [{'start': 275, 'end': 279, 'label': 'TOTAL_PRICE'}]]
# {'ent_type': {'correct': 17, 'incorrect': 0, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 17, 'actual': 17, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}, 'partial': {'correct': 17, 'incorrect': 0, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 17, 'actual': 17, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}, 'strict': {'correct': 17, 'incorrect': 0, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 17, 'actual': 17, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}, 'exact': {'correct': 17, 'incorrect': 0, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 17, 'actual': 17, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}}
#
# 3
# [[{'start': 0, 'end': 5, 'label': 'MERCHANT'}], [{'start': 6, 'end': 22, 'label': 'ADDRESS'}], [{'start': 0, 'end': 0, 'label': 'CITY'}], [{'start': 23, 'end': 25, 'label': 'STATE'}], [{'start': 32, 'end': 44, 'label': 'PHONE'}], [{'start': -1, 'end': -1, 'label': 'TAX'}], [{'start': 220, 'end': 225, 'label': 'TOTAL'}], [{'start': 606, 'end': 618, 'label': 'DATE'}], [{'start': 619, 'end': 626, 'label': 'TIME'}], [{'start': 85, 'end': 108, 'label': 'ITEM_DESC'}], [{'start': 8, 'end': 9, 'label': 'QTY'}], [{'start': 109, 'end': 113, 'label': 'UNIT_PRICE'}], [{'start': 109, 'end': 113, 'label': 'TOTAL_PRICE'}], [{'start': 117, 'end': 133, 'label': 'ITEM_DESC'}], [{'start': 7, 'end': 8, 'label': 'QTY'}], [{'start': 137, 'end': 141, 'label': 'UNIT_PRICE'}], [{'start': -1, 'end': -1, 'label': 'TOTAL_PRICE'}]]
# {'ent_type': {'correct': 16, 'incorrect': 0, 'partial': 0, 'missed': 1, 'spurious': 1, 'possible': 17, 'actual': 17, 'precision': 0.9411764705882353, 'recall': 0.9411764705882353, 'f1': 0.9411764705882353}, 'partial': {'correct': 15, 'incorrect': 0, 'partial': 1, 'missed': 1, 'spurious': 1, 'possible': 17, 'actual': 17, 'precision': 0.9117647058823529, 'recall': 0.9117647058823529, 'f1': 0.9117647058823528}, 'strict': {'correct': 15, 'incorrect': 1, 'partial': 0, 'missed': 1, 'spurious': 1, 'possible': 17, 'actual': 17, 'precision': 0.8823529411764706, 'recall': 0.8823529411764706, 'f1': 0.8823529411764706}, 'exact': {'correct': 15, 'incorrect': 1, 'partial': 0, 'missed': 1, 'spurious': 1, 'possible': 17, 'actual': 17, 'precision': 0.8823529411764706, 'recall': 0.8823529411764706, 'f1': 0.8823529411764706}}
#
# 4
# [[{'start': 195, 'end': 205, 'label': 'MERCHANT'}], [{'start': 270, 'end': 285, 'label': 'ADDRESS'}], [{'start': 286, 'end': 293, 'label': 'CITY'}], [{'start': 294, 'end': 296, 'label': 'STATE'}], [{'start': 308, 'end': 320, 'label': 'PHONE'}], [{'start': 447, 'end': 451, 'label': 'TAX'}], [{'start': 467, 'end': 470, 'label': 'TOTAL'}], [{'start': 323, 'end': 333, 'label': 'DATE'}], [{'start': 334, 'end': 342, 'label': 'TIME'}], [{'start': 360, 'end': 366, 'label': 'ITEM_DESC'}], [{'start': 230, 'end': 231, 'label': 'QTY'}], [{'start': 367, 'end': 371, 'label': 'UNIT_PRICE'}], [{'start': 367, 'end': 371, 'label': 'TOTAL_PRICE'}], [{'start': 411, 'end': 423, 'label': 'ITEM_DESC'}], [{'start': 230, 'end': 231, 'label': 'QTY'}], [{'start': 424, 'end': 428, 'label': 'UNIT_PRICE'}], [{'start': 424, 'end': 428, 'label': 'TOTAL_PRICE'}]]
# {'ent_type': {'correct': 17, 'incorrect': 0, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 17, 'actual': 17, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}, 'partial': {'correct': 17, 'incorrect': 0, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 17, 'actual': 17, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}, 'strict': {'correct': 17, 'incorrect': 0, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 17, 'actual': 17, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}, 'exact': {'correct': 17, 'incorrect': 0, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 17, 'actual': 17, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}}
#
# 5
# [[{'start': 85, 'end': 94, 'label': 'MERCHANT'}], [{'start': 102, 'end': 118, 'label': 'ADDRESS'}], [{'start': 119, 'end': 127, 'label': 'CITY'}], [{'start': 129, 'end': 131, 'label': 'STATE'}], [{'start': 143, 'end': 156, 'label': 'PHONE'}], [{'start': 303, 'end': 307, 'label': 'TAX'}], [{'start': 314, 'end': 318, 'label': 'TOTAL'}], [{'start': 157, 'end': 166, 'label': 'DATE'}], [{'start': 167, 'end': 177, 'label': 'TIME'}], [{'start': 210, 'end': 222, 'label': 'ITEM_DESC'}], [{'start': 71, 'end': 72, 'label': 'QTY'}], [{'start': -1, 'end': -1, 'label': 'UNIT_PRICE'}], [{'start': 294, 'end': 298, 'label': 'TOTAL_PRICE'}]]
# {'ent_type': {'correct': 13, 'incorrect': 0, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 13, 'actual': 13, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}, 'partial': {'correct': 13, 'incorrect': 0, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 13, 'actual': 13, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}, 'strict': {'correct': 13, 'incorrect': 0, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 13, 'actual': 13, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}, 'exact': {'correct': 13, 'incorrect': 0, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 13, 'actual': 13, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}}
#
# 6
# [[{'start': -1, 'end': -1, 'label': 'MERCHANT'}], [{'start': 0, 'end': 0, 'label': 'ADDRESS'}], [{'start': 0, 'end': 0, 'label': 'CITY'}], [{'start': 0, 'end': 0, 'label': 'STATE'}], [{'start': -1, 'end': -1, 'label': 'PHONE'}], [{'start': 389, 'end': 393, 'label': 'TAX'}], [{'start': 400, 'end': 404, 'label': 'TOTAL'}], [{'start': 64, 'end': 72, 'label': 'DATE'}], [{'start': 73, 'end': 78, 'label': 'TIME'}], [{'start': 113, 'end': 125, 'label': 'ITEM_DESC'}], [{'start': 62, 'end': 63, 'label': 'QTY'}], [{'start': 126, 'end': 131, 'label': 'UNIT_PRICE'}], [{'start': 126, 'end': 131, 'label': 'TOTAL_PRICE'}], [{'start': 144, 'end': 155, 'label': 'ITEM_DESC'}], [{'start': 62, 'end': 63, 'label': 'QTY'}], [{'start': 157, 'end': 162, 'label': 'UNIT_PRICE'}], [{'start': 157, 'end': 162, 'label': 'TOTAL_PRICE'}], [{'start': 175, 'end': 185, 'label': 'ITEM_DESC'}], [{'start': 62, 'end': 63, 'label': 'QTY'}], [{'start': 188, 'end': 191, 'label': 'UNIT_PRICE'}], [{'start': 188, 'end': 191, 'label': 'TOTAL_PRICE'}], [{'start': 207, 'end': 218, 'label': 'ITEM_DESC'}], [{'start': 62, 'end': 63, 'label': 'QTY'}], [{'start': 220, 'end': 224, 'label': 'UNIT_PRICE'}], [{'start': 220, 'end': 224, 'label': 'TOTAL_PRICE'}], [{'start': 239, 'end': 249, 'label': 'ITEM_DESC'}], [{'start': 62, 'end': 63, 'label': 'QTY'}], [{'start': 252, 'end': 256, 'label': 'UNIT_PRICE'}], [{'start': 252, 'end': 256, 'label': 'TOTAL_PRICE'}], [{'start': 272, 'end': 283, 'label': 'ITEM_DESC'}], [{'start': 62, 'end': 63, 'label': 'QTY'}], [{'start': 285, 'end': 289, 'label': 'UNIT_PRICE'}], [{'start': 285, 'end': 289, 'label': 'TOTAL_PRICE'}], [{'start': 361, 'end': 364, 'label': 'DISCOUNT'}], [{'start': 323, 'end': 330, 'label': 'ITEM_DESC'}], [{'start': 62, 'end': 63, 'label': 'QTY'}], [{'start': 331, 'end': 336, 'label': 'UNIT_PRICE'}], [{'start': 331, 'end': 336, 'label': 'TOTAL_PRICE'}], [{'start': 62, 'end': 63, 'label': 'QTY'}], [{'start': 285, 'end': 289, 'label': 'UNIT_PRICE'}], [{'start': 285, 'end': 289, 'label': 'TOTAL_PRICE'}]]
# {'ent_type': {'correct': 33, 'incorrect': 0, 'partial': 0, 'missed': 7, 'spurious': 7, 'possible': 40, 'actual': 40, 'precision': 0.825, 'recall': 0.825, 'f1': 0.825}, 'partial': {'correct': 28, 'incorrect': 0, 'partial': 5, 'missed': 7, 'spurious': 7, 'possible': 40, 'actual': 40, 'precision': 0.7625, 'recall': 0.7625, 'f1': 0.7625}, 'strict': {'correct': 28, 'incorrect': 5, 'partial': 0, 'missed': 7, 'spurious': 7, 'possible': 40, 'actual': 40, 'precision': 0.7, 'recall': 0.7, 'f1': 0.7}, 'exact': {'correct': 28, 'incorrect': 5, 'partial': 0, 'missed': 7, 'spurious': 7, 'possible': 40, 'actual': 40, 'precision': 0.7, 'recall': 0.7, 'f1': 0.7}}
#
# 7
# [[{'start': 0, 'end': 14, 'label': 'MERCHANT'}], [{'start': 26, 'end': 48, 'label': 'ADDRESS'}], [{'start': 49, 'end': 57, 'label': 'CITY'}], [{'start': 59, 'end': 61, 'label': 'STATE'}], [{'start': 68, 'end': 81, 'label': 'PHONE'}], [{'start': 488, 'end': 492, 'label': 'TAX'}], [{'start': 195, 'end': 199, 'label': 'TOTAL'}], [{'start': 106, 'end': 114, 'label': 'DATE'}], [{'start': 115, 'end': 122, 'label': 'TIME'}], [{'start': 132, 'end': 144, 'label': 'ITEM_DESC'}], [{'start': 26, 'end': 27, 'label': 'QTY'}], [{'start': 145, 'end': 149, 'label': 'UNIT_PRICE'}], [{'start': 461, 'end': 465, 'label': 'TOTAL_PRICE'}]]
# {'ent_type': {'correct': 13, 'incorrect': 0, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 13, 'actual': 13, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}, 'partial': {'correct': 13, 'incorrect': 0, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 13, 'actual': 13, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}, 'strict': {'correct': 13, 'incorrect': 0, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 13, 'actual': 13, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}, 'exact': {'correct': 13, 'incorrect': 0, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 13, 'actual': 13, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}}
#
# 8
# [[{'start': 14, 'end': 26, 'label': 'MERCHANT'}], [{'start': 0, 'end': 0, 'label': 'ADDRESS'}], [{'start': 0, 'end': 0, 'label': 'CITY'}], [{'start': 0, 'end': 0, 'label': 'STATE'}], [{'start': 32, 'end': 40, 'label': 'PHONE'}], [{'start': 513, 'end': 517, 'label': 'TAX'}], [{'start': 309, 'end': 313, 'label': 'TOTAL'}], [{'start': 71, 'end': 81, 'label': 'DATE'}], [{'start': 82, 'end': 90, 'label': 'TIME'}], [{'start': 363, 'end': 380, 'label': 'ITEM_DESC'}], [{'start': 179, 'end': 180, 'label': 'QTY'}], [{'start': 382, 'end': 386, 'label': 'UNIT_PRICE'}], [{'start': 382, 'end': 386, 'label': 'TOTAL_PRICE'}], [{'start': 391, 'end': 417, 'label': 'ITEM_DESC'}], [{'start': 179, 'end': 180, 'label': 'QTY'}], [{'start': 419, 'end': 423, 'label': 'UNIT_PRICE'}], [{'start': 419, 'end': 423, 'label': 'TOTAL_PRICE'}]]
# {'ent_type': {'correct': 17, 'incorrect': 0, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 17, 'actual': 17, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}, 'partial': {'correct': 16, 'incorrect': 0, 'partial': 1, 'missed': 0, 'spurious': 0, 'possible': 17, 'actual': 17, 'precision': 0.9705882352941176, 'recall': 0.9705882352941176, 'f1': 0.9705882352941176}, 'strict': {'correct': 16, 'incorrect': 1, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 17, 'actual': 17, 'precision': 0.9411764705882353, 'recall': 0.9411764705882353, 'f1': 0.9411764705882353}, 'exact': {'correct': 16, 'incorrect': 1, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 17, 'actual': 17, 'precision': 0.9411764705882353, 'recall': 0.9411764705882353, 'f1': 0.9411764705882353}}
#
# 9
# [[{'start': 0, 'end': 18, 'label': 'MERCHANT'}], [{'start': 42, 'end': 56, 'label': 'ADDRESS'}], [{'start': 65, 'end': 73, 'label': 'CITY'}], [{'start': 75, 'end': 77, 'label': 'STATE'}], [{'start': 29, 'end': 41, 'label': 'PHONE'}], [{'start': 243, 'end': 247, 'label': 'TAX'}], [{'start': 256, 'end': 261, 'label': 'TOTAL'}], [{'start': 808, 'end': 818, 'label': 'DATE'}], [{'start': 819, 'end': 827, 'label': 'TIME'}], [{'start': 89, 'end': 107, 'label': 'ITEM_DESC'}], [{'start': 37, 'end': 38, 'label': 'QTY'}], [{'start': 109, 'end': 113, 'label': 'UNIT_PRICE'}], [{'start': 109, 'end': 113, 'label': 'TOTAL_PRICE'}], [{'start': 117, 'end': 139, 'label': 'ITEM_DESC'}], [{'start': 37, 'end': 38, 'label': 'QTY'}], [{'start': 141, 'end': 145, 'label': 'UNIT_PRICE'}], [{'start': 141, 'end': 145, 'label': 'TOTAL_PRICE'}], [{'start': 149, 'end': 172, 'label': 'ITEM_DESC'}], [{'start': 85, 'end': 86, 'label': 'QTY'}], [{'start': 178, 'end': 182, 'label': 'UNIT_PRICE'}], [{'start': 187, 'end': 192, 'label': 'TOTAL_PRICE'}]]
# {'ent_type': {'correct': 21, 'incorrect': 0, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 21, 'actual': 21, 'precision': 1.0, 'recall': 1.0, 'f1': 1.0}, 'partial': {'correct': 20, 'incorrect': 0, 'partial': 1, 'missed': 0, 'spurious': 0, 'possible': 21, 'actual': 21, 'precision': 0.9761904761904762, 'recall': 0.9761904761904762, 'f1': 0.9761904761904762}, 'strict': {'correct': 20, 'incorrect': 1, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 21, 'actual': 21, 'precision': 0.9523809523809523, 'recall': 0.9523809523809523, 'f1': 0.9523809523809523}, 'exact': {'correct': 20, 'incorrect': 1, 'partial': 0, 'missed': 0, 'spurious': 0, 'possible': 21, 'actual': 21, 'precision': 0.9523809523809523, 'recall': 0.9523809523809523, 'f1': 0.9523809523809523}}

# %%
zip(ner_scores_golden, ner_scores_classified)

# %%
### IMPORTANT CELL
import json

def find_span(text, entity_text):
    start = text.find(entity_text)
    if start == -1:
        return (-1, -1), entity_text
    end = start + len(entity_text)
    return (start, end), entity_text

def convert_to_prodigy_spans(receipt_text, entities):
    text_vals = {}
    #entities = json.loads(entities)
    prodigy_data = []
    receipt_info = entities["ReceiptInfo"]

    for label, entity_text in [
        ("MERCHANT", receipt_info["merchant"]),
        ("ADDRESS", receipt_info["address"]),
        ("CITY", receipt_info["city"]),
        ("STATE", receipt_info["state"]),
        ("PHONE", receipt_info["phoneNumber"]),
        ("TAX", str(receipt_info["tax"])),
        ("TOTAL", str(receipt_info["total"])),
        ("DATE", receipt_info["receiptDate"]),
        ("TIME", receipt_info["receiptTime"])
    ]:
        span, text = find_span(receipt_text, entity_text)
        text_vals[label] = text
        if span:
            start, end = span
            prodigy_data.append({"start": start, "end": end, "label": label})

    # Process item-level entities
    for item in receipt_info["ITEMS"]:
        discount = ""
        if(item["discountAmount"] != 0.00):
            discount = str(item["discountAmount"])
        for label, entity_text in [
            ("ITEM_DESC", item["description"]),
            ("QTY", str(item["quantity"])),
            ("UNIT_PRICE", str(item["unitPrice"])),
            ("TOTAL_PRICE", str(item["totalPrice"])),
            ("DISCOUNT", discount)  # Discount might not always be present in the raw receipt text
        ]:
            if entity_text:  # Check if the entity text is not empty
                span, text = find_span(receipt_text, entity_text)
                text_vals[label] = text
                if span:
                    start, end = span
                    prodigy_data.append({"start": start, "end": end, "label": label})
    return prodigy_data, text_vals

# Example usage
# prodigy_spans_true, text_vals = convert_to_prodigy_spans(receipt_text, entities)
# print(json.dumps(prodigy_spans_true, indent=2))
# print(text_vals)

# %%
convert_to_prodigy_spans(receipt_texts[0],

# %%
s = prodigy_spans_true[2]['start']
e = prodigy_spans_true[2]['end']
receipt_text[s:e]
# Out:
# 'Kailua'

# %%
text_vals[4]
# Out:
# '(808) 555-1234'

# %%
ner_predicted = """{
  "ReceiptInfo": {
    "merchant": "Marley's",
    "address": "123 Long Rd",
    "city": "Kailua",
    "state": "HI",
    "phoneNumber": "555-1234",
    "tax": 1.15,
    "total": 14.72,
    "receiptDate": "04/12/2023",
    "ITEMS": [
      {
        "description": "APPLES (1 lb)",
        "quantity": 2,
        "unitPrice": 2.99,
        "totalPrice": 5.98,
        "discountAmount": 1.00
      },
      {
        "description": "Choco Dream Cookies",
        "quantity": 1,
        "unitPrice": 7.59,
        "totalPrice": 7.59
      }
    ]
  }
}"""

prodigy_spans_predicted, text_vals_predicted = convert_to_prodigy_spans(receipt_text, ner_predicted)
print(json.dumps(prodigy_spans_predicted, indent=2))
print(text_vals_predicted)
# Out:
# [
#   {
#     "start": 0,
#     "end": 8,
#     "label": "MERCHANT"
#   },
#   {
#     "start": 14,
#     "end": 25,
#     "label": "ADDRESS"
#   },
#   {
#     "start": 26,
#     "end": 32,
#     "label": "CITY"
#   },
#   {
#     "start": 34,
#     "end": 36,
#     "label": "STATE"
#   },
#   {
#     "start": 49,
#     "end": 57,
#     "label": "PHONE"
#   },
#   {
#     "start": 252,
#     "end": 256,
#     "label": "TAX"
#   },
#   {
#     "start": 264,
#     "end": 269,
#     "label": "TOTAL"
#   },
#   {
#     "start": 86,
#     "end": 96,
#     "label": "DATE"
#   },
#   {
#     "start": [
#       140,
#       153
#     ],
#     "end": "APPLES (1 lb)",
#     "label": "ITEM_DESC"
#   },
#   {
#     "start": [
#       15,
#       16
#     ],
#     "end": "2",
#     "label": "QTY"
#   },
#   {
#     "start": [
#       154,
#       158
#     ],
#     "end": "2.99",
#     "label": "UNIT_PRICE"
#   },
#   {
#     "start": [
#       161,
#       165
#     ],
#     "end": "5.98",
#     "label": "TOTAL_PRICE"
#   },
#   {
#     "start": [
#       173,
#       176
#     ],
#     "end": "1.0",
#     "label": "DISCOUNT"
#   },
#   {
#     "start": [
#       183,
#       202
#     ],
#     "end": "Choco Dream Cookies",
#     "label": "ITEM_DESC"
#   },
#   {
#     "start": [
#       14,
#       15
#     ],
#     "end": "1",
#     "label": "QTY"
#   },
#   {
#     "start": [
#       203,
#       207
#     ],
#     "end": "7.59",
#     "label": "UNIT_PRICE"
#   },
#   {
#     "start": [
#       203,
#       207
#     ],
#     "end": "7.59",
#     "label": "TOTAL_PRICE"
#   }
# ]
# ["Marley's", '123 Long Rd', 'Kailua', 'HI', '555-1234', '1.15', '14.72', '04/12/2023']

# %% [markdown]
# ### EXAMPLE FROM THE DOCUMENTATION

# %%
"https://pypi.org/project/nervaluate/#:~:text=tab%20delimited%20strings.-,Prodigy%20spans,-true%20%3D%20%5B%0A%20%20%20%20%5B%7B%22label%22%3A%20%22PER"

true = [
    [{"label": "PER", "start": 2, "end": 4}],
    [{"label": "LOC", "start": 1, "end": 2},
     {"label": "LOC", "start": 3, "end": 4}]
]

pred = [
    [{"label": "PER", "start": 2, "end": 4}],
    [{"label": "LOC", "start": 1, "end": 2},
     {"label": "LOC", "start": 3, "end": 4}]
]

from nervaluate import Evaluator

evaluator = Evaluator(true, pred, tags=['LOC', 'PER'])

# Returns overall metrics and metrics for each tag

results, results_per_tag = evaluator.evaluate()

results
# Out:
# {'ent_type': {'correct': 3,
#   'incorrect': 0,
#   'partial': 0,
#   'missed': 0,
#   'spurious': 0,
#   'possible': 3,
#   'actual': 3,
#   'precision': 1.0,
#   'recall': 1.0,
#   'f1': 1.0},
#  'partial': {'correct': 3,
#   'incorrect': 0,
#   'partial': 0,
#   'missed': 0,
#   'spurious': 0,
#   'possible': 3,
#   'actual': 3,
#   'precision': 1.0,
#   'recall': 1.0,
#   'f1': 1.0},
#  'strict': {'correct': 3,
#   'incorrect': 0,
#   'partial': 0,
#   'missed': 0,
#   'spurious': 0,
#   'possible': 3,
#   'actual': 3,
#   'precision': 1.0,
#   'recall': 1.0,
#   'f1': 1.0},
#  'exact': {'correct': 3,
#   'incorrect': 0,
#   'partial': 0,
#   'missed': 0,
#   'spurious': 0,
#   'possible': 3,
#   'actual': 3,
#   'precision': 1.0,
#   'recall': 1.0,
#   'f1': 1.0}}

# %%
# ?Evaluator
# Out:
# Init signature: Evaluator(true, pred, tags, loader=None)
# Docstring:      <no docstring>
# Init docstring:
# File:           ~/anaconda3/lib/python3.11/site-packages/nervaluate/nervaluate.py
# Type:           type
# Subclasses:

# %%
results_per_tag
# Out:
# {'LOC': {'ent_type': {'correct': 2,
#    'incorrect': 0,
#    'partial': 0,
#    'missed': 0,
#    'spurious': 0,
#    'possible': 2,
#    'actual': 2,
#    'precision': 1.0,
#    'recall': 1.0,
#    'f1': 1.0},
#   'partial': {'correct': 2,
#    'incorrect': 0,
#    'partial': 0,
#    'missed': 0,
#    'spurious': 0,
#    'possible': 2,
#    'actual': 2,
#    'precision': 1.0,
#    'recall': 1.0,
#    'f1': 1.0},
#   'strict': {'correct': 2,
#    'incorrect': 0,
#    'partial': 0,
#    'missed': 0,
#    'spurious': 0,
#    'possible': 2,
#    'actual': 2,
#    'precision': 1.0,
#    'recall': 1.0,
#    'f1': 1.0},
#   'exact': {'correct': 2,
#    'incorrect': 0,
#    'partial': 0,
#    'missed': 0,
#    'spurious': 0,
#    'possible': 2,
#    'actual': 2,
#    'precision': 1.0,
#    'recall': 1.0,
#    'f1': 1.0}},
#  'PER': {'ent_type': {'correct': 1,
#    'incorrect': 0,
#    'partial': 0,
#    'missed': 0,
#    'spurious': 0,
#    'possible': 1,
#    'actual': 1,
#    'precision': 1.0,
#    'recall': 1.0,
#    'f1': 1.0},
#   'partial': {'correct': 1,
#    'incorrect': 0,
#    'partial': 0,
#    'missed': 0,
#    'spurious': 0,
#    'possible': 1,
#    'actual': 1,
#    'precision': 1.0,
#    'recall': 1.0,
#    'f1': 1.0},
#   'strict': {'correct': 1,
#    'incorrect': 0,
#    'partial': 0,
#    'missed': 0,
#    'spurious': 0,
#    'possible': 1,
#    'actual': 1,
#    'precision': 1.0,
#    'recall': 1.0,
#    'f1': 1.0},
#   'exact': {'correct': 1,
#    'incorrect': 0,
#    'partial': 0,
#    'missed': 0,
#    'spurious': 0,
#    'possible': 1,
#    'actual': 1,
#    'precision': 1.0,
#    'recall': 1.0,
#    'f1': 1.0}}}
